# %% [markdown]
# 🔹 НЕДЕЛЯ 1 — PyTorch + основы нейросетей
#
# 📅 День 1 — Что такое нейросети и зачем CNN
#
# Цель: понять базовые идеи DL и CV
#
# Теория:
#
# Coursera (RU):
# 👉 https://www.coursera.org/learn/neural-networks-deep-learning-ru
#
# ▶️ Неделя 1: Введение в нейронные сети
#
# Практика:
#
# установить:
#
# pip install torch torchvision matplotlib numpy
#
#
# ✅ Результат: понимаешь, что такое нейрон, веса, функция активации

# %%
pip install torch torchvision matplotlib numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    ---------------------------------------- 0.5/113.8 MB 4.2 MB/s eta 0:00:27
#     --------------------------------------- 2.4/113.8 MB 7.5 MB/s eta 0:00:15
#    - -------------------------------------- 4.7/113.8 MB 9.2 MB/s eta 0:00:12
#    -- ------------------------------------- 6.6/113.8 MB 9.4 MB/s eta 0:00:12
#    --- ------------------------------------ 8.7/113.8 MB 9.4 MB/s eta 0:00:12
#    --- ------------------------------------ 10.5/113.8 MB 9.4 MB/s eta 0:00:12
#    ---- ----------------------------------- 11.8/113.8 MB 9.5 MB/s eta 0:00:11
#    ---- ----------------------------------- 12.6/113.8 MB 8.6 MB/s eta 0:00:12
#    ---- ----------------------------------- 13.4/113.8 MB 7.9 MB/s eta 0:00:13
#    ---- ----------------------------------- 14.2/113.8 MB 7.4 MB/s eta 0:00:14
# ...

# %% [markdown]
# 📅 День 2 — PyTorch tensors и autograd
#
# Цель: научиться работать с тензорами
#
# Материалы:
#
# PyTorch Tutorial:
# 👉 https://pytorch.org/tutorials/beginner/basics/tensorqs_tutorial.html
#
# CUDA для PyTorch:
# 👉 https://github.com/ArtyomR/PyTorch-CUDA/blob/main/PyTorch%20installation%20with%20CUDA.ipynb
#
# CUDA vs CPU (tested on local PC, not tested on Googlr Colab):
# 👉 1W2. Processing Speed CUDA vs CPU.ipynb
#
# Autograd:
# 👉 https://pytorch.org/tutorials/beginner/basics/autogradqs_tutorial.html
#
# Практика:
#
# создать тензоры
#
# сложение, умножение
#
# .backward()
#
# ✅ Результат: понимаешь, откуда берутся градиенты

# %% [markdown]
# 📅 День 3 — Первая нейросеть на PyTorch
#
# Цель: написать простую модель
#
# Материалы:
#
# PyTorch:
# 👉 https://pytorch.org/tutorials/beginner/basics/buildmodel_tutorial.html
#
# Практика:
#
# nn.Linear
#
# nn.ReLU
#
# nn.Sequential
#
# ✅ Результат: умеешь создавать модель как класс

# %%
📅 День 4 — Dataset и DataLoader

Цель: подготовка данных

Материалы:

Dataset & DataLoader:
👉 https://pytorch.org/tutorials/beginner/basics/data_tutorial.html

Практика:

загрузить MNIST

вывести batch изображений

# %%
📅 День 5 — Training loop (самое важное)

Цель: научиться обучать модель

Материалы:

PyTorch training loop:
👉 https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html

Практика:

loss

optimizer

цикл обучения

👉 Дополненая тетрадка с настройкой работы с CUDA и проверкой классификации: optimization_tutorial (+cuda)

✅ Результат: понимаешь, как реально обучаются сети

✅ Итог недели: ты уже умеешь обучать модели на PyTorch
