# %% [markdown]
# 🔹 НЕДЕЛЯ 3 — CNN и Deep Learning для CV (PyTorch)
# 📅 День 11 — CNN: теория
#
# Материалы:
#
# 📺 Бесплатные видео (EN/RU)
#
# 🎥 Свёрточные нейронные сети: как они работают — на русском (OTUS IT)
# 👉 Смотрите на YouTube:
# https://www.youtube.com/watch?v=2N-9FDeG0dQ
# – базовая структура CNN, зачем нужны свертки и пулинг, ключевые архитектуры CNN в CV.
#
# 📚 Поясняющие тексты (RU/EN)
#
# 🧠 Хабр: Наглядно о том, как работает CNN (RU)
# 👉 Простой текст с основами свёртки и структуры сетей.
# https://habr.com/ru/companies/skillfactory/articles/565232/
#
# 🧠 Хабр: Свёрточные нейронные сети — от основ до современных технологий (RU)
# 👉 Более подробный обзор архитектур и принципов.
# https://habr.com/ru/articles/887268/
#
# Coursera (RU):
# ▶️ CNN модуль
# 👉 Convolutional Neural Networks (курс от DeepLearning.AI на Coursera)
#  — этот курс полностью посвящён CNN и учит строить, тренировать и применять сверточные сети для задач компьютерного зрения, включая классификацию, детекцию и другие применения.
# https://www.coursera.org/learn/convolutional-neural-networks
#
# Stanford CS231n (EN):
# 👉 http://cs231n.stanford.edu/

# %% [markdown]
# 📅 День 12 — CNN на PyTorch
#
# Материалы:
#
# PyTorch CNN tutorial:
# 👉 https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
#
# Практика:
#
# Conv2D
#
# MaxPool
#
# обучение CIFAR-10

# %% [markdown]
# 📅 День 13 — Transfer Learning
#
# Материалы:
#
# PyTorch TL tutorial:
# 👉 https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
#
# Практика:
#
# ResNet18 pretrained
#
# fine-tuning

# %% [markdown]
# 📅 День 14 —  CV with PyTorch
#
# Практическое задание
#
# Сделай:
#
# ✅ классификацию Cats vs Dogs через ResNet18.
#
# Шаги:
#
# загрузить pretrained model
#
# заморозить backbone
#
# заменить последний слой:
#
# model.fc = nn.Linear(512, 2)
#
# обучить только classifier

# %% [markdown]
# 📅 День 15 — Fast.ai - дополнительно, по желанию
#
# Материалы:
#
# https://course.fast.ai/
#
# ▶️ Lesson 1
#
# Практика:
#
# классификация изображений
